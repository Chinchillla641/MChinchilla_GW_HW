# %% [markdown]
# **BIG BIG HINT! Look in the instructions to guide you on this task.**

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# load CSV
df = pd.read_csv("Resources/2016-FCC-New-Coders-Survey-Data.csv", low_memory = False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Read with pandas

# %%
# Inspect all columns
df.count()
# Out:
# Age                      13613
# AttendedBootcamp         15380
# BootcampFinish             933
# BootcampFullJobAfter       635
# BootcampLoanYesNo          934
# BootcampMonthsAgo          631
# BootcampName               895
# BootcampPostSalary         330
# BootcampRecommend          937
# ChildrenNumber            2554
# CityPopulation           13630
# CodeEventBootcamp           42
# CodeEventCoffee           2077
# CodeEventConferences      2898
# CodeEventDjangoGirls        18
# CodeEventGameJam            22
# CodeEventGirlDev           558
# CodeEventHackathons       2422
# CodeEventMeetup            313
# CodeEventNodeSchool        480
# CodeEventNone             8900
# CodeEventOther             921
# CodeEventRailsBridge       255
# CodeEventRailsGirls         14
# CodeEventStartUpWknd       743
# CodeEventWomenCode         711
# CodeEventWorkshop           23
# CommuteTime               8339
# CountryCitizen           13654
# CountryLive              13610
# ...

# %%
df.shape
# Out:
# (15620, 113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
columns = [0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]
extract_df = df.iloc[:, columns]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
extract_df['AttendedBootcamp'] = extract_df['AttendedBootcamp'].apply(lambda x: "no" if x==0 else "yes")
extract_df.head()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               no             NaN                   NaN
# 1  22.0               no             NaN                   NaN
# 2  19.0               no             NaN                   NaN
# 3  26.0               no             NaN                   NaN
# 4  20.0               no             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# ...

# %%
# Calculate total number of respondents in survey
total_respondents = extract_df.shape[0]

# %%
# Extract rows corresponding only to people who attended a bootcamp
attend_df = extract_df.loc[extract_df["AttendedBootcamp"] == "yes", :]
attend_df.head()
# Out:
#       Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 58   24.0              yes             NaN                   NaN
# 93   32.0              yes             1.0                   0.0
# 97   26.0              yes             1.0                   1.0
# 130  41.0              yes             1.0                   1.0
# 159  26.0              yes             1.0                   0.0
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 58                 NaN                 NaN                NaN             NaN
# 93                 0.0                 NaN                0.0             NaN
# 97                 0.0             45000.0                0.0             NaN
# 130                1.0             75000.0                1.0             3.0
# 159                0.0                 NaN                0.0             NaN
#
#                     CityPopulation  CodeEventBootcamp  \
# ...

# %%
# Calculate average age of attendees
mean_age = attend_df["Age"].mean()
# Calculate how many people attended a bootcamp
total_attend = attend_df.shape[0]

# Calculate how many attendees hold degrees
attend_df["Degree"] = pd.Series("Yes", index=attend_df.index)

attend_df.loc[attend_df.SchoolDegree == "some college credit, no degree", "Degree"] = "No"
attend_df.loc[attend_df.SchoolDegree == "high school diploma or equivalent (GED)", "Degree"] = "No"
attend_df.loc[attend_df.SchoolDegree == "trade, technical, or vocational training", "Degree"] = "No"
attend_df.loc[attend_df.SchoolDegree == "some high school", "Degree"] = "No"
attend_df.loc[attend_df.SchoolDegree == "no high school (secondary school)", "Degree"] = "No"

coll_degree = attend_df["Degree"].value_counts(dropna = False)["Yes"]

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
male = attend_df["Gender"].value_counts()["male"]
female = attend_df["Gender"].value_counts()["female"]
nangen = len(attend_df) - attend_df['Gender'].count()
other = total_attend - (male + female + nangen)

# Calculate percentage of respondents who attended a bootcamp
pct_attend = total_attend / total_respondents

# Calculate percentage of respondents belonging to each gender
pct_male = 100 * male / total_attend
pct_female = 100 * female / total_attend
pct_other = 100 * other / total_attend

# Calculate percentage of attendees with a school degree
pct_degree = 100 * coll_degree / total_attend

# Calculate average post-bootcamp salary
mean_sal = attend_df["BootcampPostSalary"].mean()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Create a new table consolodating above calculations
table = pd.DataFrame = ({"Total Surveyed": [total_respondents],
                        "Total Bootcamp Atendees": [total_attend],
                        "% attneded bootcamp": [pct_attend],
                        "Avg. Age": [mean_age],
                        "% Male": [male],
                        "% Female": [female],
                        "% Non Gender": [other],
                        "Has a degree": [pct_degree],
                        "Average Post Bootcamp Salary": mean_sal})

# table = table[["Total Surveyed", "Total Bootcamp Atendees", "% attneded bootcamp", "Avg. Age", "% Male", "% Female", \
#                "% Non Gender", "Has a degree", "Average Post Bootcamp Salary"]]
table.round(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-af144bce9ace> in <module>
#      12 # table = table[["Total Surveyed", "Total Bootcamp Atendees", "% attneded bootcamp", "Avg. Age", "% Male", "% Female", \
#      13 #                "% Non Gender", "Has a degree", "Average Post Bootcamp Salary"]]
# ---> 14 table.round(2)
#
# AttributeError: 'dict' object has no attribute 'round'

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
